# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 761.4 kB/s eta 0:00:000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.5/792.5 kB 6.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 32.8 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.10.0.82
#     Uninstalling opencv-python-headless-4.10.0.82:
#       Successfully uninstalled opencv-python-headless-4.10.0.82
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# ...

# %%
# !pip uninstall wandb -y
# Out:
# Found existing installation: wandb 0.17.0
# Uninstalling wandb-0.17.0:
#   Successfully uninstalled wandb-0.17.0

# %% [markdown]
# ## Get Datasets

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="h6w9f5nSVrvuqSlAhFuB")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-2 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 3931.36it/s]

# %%
dataset.location
# Out:
# '/kaggle/working/football-players-detection-2'

# %%
import shutil

shutil.move('football-players-detection-2/train',
           'football-players-detection-2/football-players-detection-2/train')

shutil.move('football-players-detection-2/test',
           'football-players-detection-2/football-players-detection-2/test')

shutil.move('football-players-detection-2/valid',
           'football-players-detection-2/football-players-detection-2/valid')
# Out:
# 'football-players-detection-2/football-players-detection-2/valid'

# %% [markdown]
# ## Training (using ultralytics to train YOLO-V5)

# %%
# !yolo task=detect mode=train model=yolov5x.pt data=dataset.location/data.yaml epochs=100 imgsz=640

# %%
from ultralytics import YOLO

model = YOLO("yolov5m.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data=f"{dataset.location}/data.yaml", epochs=100, imgsz=640)
# Out:
# PRO TIP 💡 Replace 'model=yolov5m.pt' with new 'model=yolov5mu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 48.2M/48.2M [00:00<00:00, 214MB/s]
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
api_key="876ad31389f9d4edc260ef578c2fc078cf3c71d6"
