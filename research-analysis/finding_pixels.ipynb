# %%
import cv2
import os
os.chdir('D:/Python Networking Projects/bundesliga_cv_project')

video_path = 'input_video/C35bd9041_0 (57).mp4'
print(os.path.exists(video_path))
cap = cv2.VideoCapture(video_path)

ret, frame = cap.read()
cap.release()

import matplotlib.pyplot as plt

plt.imshow(frame)
# Out:
# True

# %%
cv2.imwrite('output_images/frame.jpg', frame)
# Out:
# True

# %%
from datetime import datetime
a = datetime.now()
for i in range(1000):
    pass
b = datetime.now()
print(b-a)
# Out:
# 0:00:00

# %%
str(b-a)
# Out:
# '0:00:00'
